# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys

nb_path = '/content/drive/MyDrive/Colab Notebooks/site-packages'
sys.path.insert(0, nb_path)  # or append(nb_path)

# %%
# Standard library imports
import numpy as np

from gluonts.dataset.common import ListDataset
from gluonts.model.estimator import GluonEstimator
from gluonts.model.predictor import Predictor
from gluonts.trainer import Trainer

import mxnet as mx
from mxnet import gluon
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx.trainer import Trainer
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: gluonts.trainer is deprecated. Use gluonts.mx.trainer instead.
#   import sys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error

# %%
mx.random.seed(0)
np.random.seed(0)

# %% [markdown]
# ## **deepAR**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ppikppik/outfree_gs_boo.csv", encoding='EUC-KR')

# %%
year_start = 1985
month = 12
day = 1
cnt_year = 0
for i in df.index :
  df.loc[i,'회계년도'] = pd.Timestamp(year=year_start+cnt_year, month=12, day=1)
  cnt_year = cnt_year + 1

# %%
temp = df.set_index(df['회계년도'])
temp[{'유동자산(요약)', '매출총이익(요약)', '매출액(요약)', '당기순이익(요약)', '영업이익(요약)'}]
# Out:
#             매출총이익(요약)  유동자산(요약)  당기순이익(요약)  영업이익(요약)   매출액(요약)
# 회계년도
# 1985-12-01     8823.0     93153     2444.0    2576.0    105579
# 1986-12-01    14875.0    110459     3818.0    7120.0    152111
# 1987-12-01    20333.0    129208     4748.0   11035.0    240839
# 1988-12-01    23093.0    140120     3135.0   11398.0    277801
# 1989-12-01    20759.0    157434     1587.0    9807.0    266215
# 1990-12-01    29451.0    200084     1637.0   19810.0    280779
# 1991-12-01    22797.0    188209     3002.0   13032.0    285351
# 1992-12-01    32298.0    283401    10295.0   19108.0    324475
# 1993-12-01    44634.0    360086    14174.0   28015.0    427284
# 1994-12-01    74280.0    537065    16173.0   54482.0    523936
# 1995-12-01    88308.0    644659    19318.0   59159.0    723887
# 1996-12-01   120583.0    875692    15763.0   77714.0    980809
# 1997-12-01   131589.0    880767    10571.0   80541.0    870499
# 1998-12-01   155700.0    977137     9834.0   88619.0   1015964
# 1999-12-01   188952.0   1191673    19608.0  111660.0   1476731
# 2000-12-01   241006.0   1386759    15384.0  127423.0   1831907
# 2001-12-01   214056.0   1533136    19811.0   98718.0   2107675
# 2002-12-01   202618.0   1456663    41501.0  110501.0   2040972
# 2003-12-01   279485.0   1473119    99839.0  143284.0   2090586
# 2004-12-01   379501.0   1229534   123594.0  225429.0   2707864
# 2005-12-01   404927.0   1456656   150078.0  254845.0   3153102
# 2006-12-01   472500.0   1301303   160714.0  276065.0   3174465
# 2007-12-01   521008.0   1297856   161537.0  271411.0   3467584
# 2008-12-01   600500.0   1774927   213337.5  229122.0   4049093
# 2009-12-01   679992.0   2422545   265138.0  335578.0   5630813
# 2010-12-01   762199.0   3018745   386953.0  403370.0   5745165
# 2011-12-01   859618.0   3758242   400013.0  442044.0   6011536
# 2012-12-01   813701.2   4927769   381554.0  478323.0   6865848
# 2013-12-01   767784.4   5894188   382801.0  392046.2   7376925
# 2014-12-01   721867.6   6551877   388676.9  305769.5   7892763
# 2015-12-01   675950.8   6792046   394552.8  219492.8   8524884
# 2016-12-01   630034.0   7032214   400428.7  133216.0   8530989
# 2017-12-01   642974.0   7503603   406304.6  134874.7   7861809
# 2018-12-01   655914.0   7667877   412180.5  136533.3   8353332
# 2019-12-01   668854.0   7502377   418056.4  138192.0   9069843
# 2020-12-01   681794.0   7336877   423932.3  387819.0   9996139
# 2021-12-01   826757.0   7171377   429808.2  532659.0  10811747
# 2022-12-01   826757.0   7005877   435684.1  981918.0  10811747
# 2023-12-01   826757.0   5997754   441560.0  680931.0  10811747

# %%
def find_upper_lower_bound(df,col):
    temp = sorted(df[col])
    q1, q3 = np.percentile(temp, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    return lower_bound, upper_bound

def range_check_correct(df,col):
    cor_range = find_upper_lower_bound(df,col)
    print(cor_range)
    for i in df.index:
        if df.loc[i][col] < (float)(cor_range[0]) :
            df[col][i] = (float)(cor_range[0])
        if df.loc[i][col] > (float)(cor_range[1]) :
            df[col][i] = (float)(cor_range[1])
    return df

# %%
temp = range_check_correct(temp,'영업이익(요약)')
# Out:
# (-294324.625, 642062.375)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
temp
# Out:
#                  회사명    연도  거래소코드  ...       부채비용     비유동비율  비유동장기적합률
# 회계년도                               ...
# 1985-12-01  지에스건설(주)  1981   6360  ...  18.597705  0.260653  2.306329
# 1986-12-01  지에스건설(주)  1982   6360  ...  10.528852  0.749201  0.957382
# 1987-12-01  지에스건설(주)  1983   6360  ...  11.416639  0.517862  1.182656
# 1988-12-01  지에스건설(주)  1984   6360  ...  12.595984  0.721935  0.990255
# 1989-12-01  지에스건설(주)  1985   6360  ...  14.482049  0.759678  0.993096
# 1990-12-01  지에스건설(주)  1986   6360  ...  18.025246  1.154299  0.712439
# 1991-12-01  지에스건설(주)  1987   6360  ...   7.433893  1.853399  0.393315
# 1992-12-01  지에스건설(주)  1988   6360  ...   6.215350  1.187303  0.550647
# 1993-12-01  지에스건설(주)  1989   6360  ...   9.496575  1.111082  0.702241
# 1994-12-01  지에스건설(주)  1990   6360  ...  11.978126  1.079809  0.737432
# 1995-12-01  지에스건설(주)  1991   6360  ...  14.269137  1.079051  0.748093
# 1996-12-01  지에스건설(주)  1992   6360  ...  20.136863  0.935439  0.903624
# 1997-12-01  지에스건설(주)  1993   6360  ...  13.615721  0.760623  0.993313
# 1998-12-01  지에스건설(주)  1994   6360  ...  13.120773  1.006385  0.810218
# 1999-12-01  지에스건설(주)  1995   6360  ...  15.609129  1.307970  0.649524
# 2000-12-01  지에스건설(주)  1996   6360  ...  18.796994  0.857815  0.951491
# 2001-12-01  지에스건설(주)  1997   6360  ...  19.789052  1.334122  0.668025
# 2002-12-01  지에스건설(주)  1998   6360  ...  18.422123  1.223480  0.725384
# 2003-12-01  지에스건설(주)  1999   6360  ...   6.725431  0.275457  1.837216
# 2004-12-01  지에스건설(주)  2000   6360  ...   6.432000  0.428287  1.539767
# 2005-12-01  지에스건설(주)  2001   6360  ...   6.872357  0.445118  1.513676
# 2006-12-01  지에스건설(주)  2002   6360  ...   6.326369  0.358099  1.833122
# 2007-12-01  지에스건설(주)  2003   6360  ...   6.018839  0.251478  2.301010
# 2008-12-01  지에스건설(주)  2004   6360  ...   7.866176  0.327920  2.021149
# 2009-12-01  지에스건설(주)  2005   6360  ...   9.313722  0.374700  1.797217
# 2010-12-01  지에스건설(주)  2006   6360  ...  11.635114  0.336004  2.069643
# 2011-12-01  지에스건설(주)  2007   6360  ...  14.091804  0.328463  2.183027
# 2012-12-01  지에스건설(주)  2008   6360  ...  20.185349  0.417415  2.017072
# 2013-12-01  지에스건설(주)  2009   6360  ...  22.146055  0.476105  1.786816
# 2014-12-01  지에스건설(주)  2010   6360  ...  22.558584  0.418088  1.962303
# 2015-12-01  지에스건설(주)  2011   6360  ...  25.587200  0.538732  1.594405
# 2016-12-01  지에스건설(주)  2012   6360  ...  24.964243  0.535087  1.625563
# 2017-12-01  지에스건설(주)  2013   6360  ...  30.790875  0.667411  1.344325
# 2018-12-01  지에스건설(주)  2014   6360  ...  22.896394  0.665998  1.318595
# 2019-12-01  지에스건설(주)  2015   6360  ...  23.853017  0.658198  1.313297
# 2020-12-01  지에스건설(주)  2016   6360  ...  25.193363  0.704571  1.242580
# 2021-12-01  지에스건설(주)  2017   6360  ...  26.105568  0.374547  2.177669
# 2022-12-01  지에스건설(주)  2018   6360  ...  18.381377  0.380281  2.092309
# 2023-12-01  지에스건설(주)  2019   6360  ...  18.260879  0.437339  1.959010
#
# [39 rows x 27 columns]

# %%
prediction_window = 1

# %%
train_ds = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values[:-prediction_window] ,
      "feat_dynamic_real": [temp['유동자산(요약)'].values[:-prediction_window],temp['매출총이익(요약)'].values[:-prediction_window],temp['매출액(요약)'].values[:-prediction_window],temp['당기순이익(요약)'].values[:-prediction_window]]}],
                        freq = "365D"
)

# %%
freq = "365D"

estimator = DeepAREstimator(prediction_length = prediction_window, use_feat_dynamic_real= True , freq=freq, cell_type = 'lstm', 
                           trainer=Trainer(epochs=200, ctx = mx.context.gpu(),))

# %%
predictor = estimator.train(training_data = train_ds)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# 100%|██████████| 50/50 [00:00<00:00, 70.67it/s, epoch=1/200, avg_epoch_loss=13.1]
# 100%|██████████| 50/50 [00:00<00:00, 74.79it/s, epoch=2/200, avg_epoch_loss=12.1]
# 100%|██████████| 50/50 [00:00<00:00, 78.35it/s, epoch=3/200, avg_epoch_loss=11.6]
# 100%|██████████| 50/50 [00:00<00:00, 78.29it/s, epoch=4/200, avg_epoch_loss=11.1]
# 100%|██████████| 50/50 [00:00<00:00, 76.63it/s, epoch=5/200, avg_epoch_loss=10.6]
# 100%|██████████| 50/50 [00:00<00:00, 75.89it/s, epoch=6/200, avg_epoch_loss=10.2]
# 100%|██████████| 50/50 [00:00<00:00, 77.08it/s, epoch=7/200, avg_epoch_loss=10.2]
# 100%|██████████| 50/50 [00:00<00:00, 79.45it/s, epoch=8/200, avg_epoch_loss=10]
# 100%|██████████| 50/50 [00:00<00:00, 76.08it/s, epoch=9/200, avg_epoch_loss=9.94]
# 100%|██████████| 50/50 [00:00<00:00, 75.55it/s, epoch=10/200, avg_epoch_loss=10.1]
# 100%|██████████| 50/50 [00:00<00:00, 76.70it/s, epoch=11/200, avg_epoch_loss=9.87]
# 100%|██████████| 50/50 [00:00<00:00, 77.49it/s, epoch=12/200, avg_epoch_loss=10.1]
# 100%|██████████| 50/50 [00:00<00:00, 77.52it/s, epoch=13/200, avg_epoch_loss=9.67]
# 100%|██████████| 50/50 [00:00<00:00, 76.49it/s, epoch=14/200, avg_epoch_loss=9.99]
# 100%|██████████| 50/50 [00:00<00:00, 78.44it/s, epoch=15/200, avg_epoch_loss=9.76]
# 100%|██████████| 50/50 [00:00<00:00, 77.22it/s, epoch=16/200, avg_epoch_loss=9.77]
# 100%|██████████| 50/50 [00:00<00:00, 78.74it/s, epoch=17/200, avg_epoch_loss=9.71]
# 100%|██████████| 50/50 [00:00<00:00, 76.27it/s, epoch=18/200, avg_epoch_loss=9.73]
# 100%|██████████| 50/50 [00:00<00:00, 71.90it/s, epoch=19/200, avg_epoch_loss=9.67]
# 100%|██████████| 50/50 [00:00<00:00, 76.03it/s, epoch=20/200, avg_epoch_loss=9.49]
# 100%|██████████| 50/50 [00:00<00:00, 72.74it/s, epoch=21/200, avg_epoch_loss=9.99]
# 100%|██████████| 50/50 [00:00<00:00, 70.78it/s, epoch=22/200, avg_epoch_loss=9.81]
# 100%|██████████| 50/50 [00:00<00:00, 72.72it/s, epoch=23/200, avg_epoch_loss=9.47]
# 100%|██████████| 50/50 [00:00<00:00, 76.10it/s, epoch=24/200, avg_epoch_loss=10.2]
# 100%|██████████| 50/50 [00:00<00:00, 74.77it/s, epoch=25/200, avg_epoch_loss=9.63]
# 100%|██████████| 50/50 [00:00<00:00, 75.15it/s, epoch=26/200, avg_epoch_loss=9.48]
# 100%|██████████| 50/50 [00:00<00:00, 71.21it/s, epoch=27/200, avg_epoch_loss=9.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.31it/s, epoch=28/200, avg_epoch_loss=9.81]
# 100%|██████████| 50/50 [00:00<00:00, 77.86it/s, epoch=29/200, avg_epoch_loss=9.78]
# 100%|██████████| 50/50 [00:00<00:00, 77.91it/s, epoch=30/200, avg_epoch_loss=9.77]
# 100%|██████████| 50/50 [00:00<00:00, 79.11it/s, epoch=31/200, avg_epoch_loss=9.56]
# 100%|██████████| 50/50 [00:00<00:00, 75.33it/s, epoch=32/200, avg_epoch_loss=9.6]
# 100%|██████████| 50/50 [00:00<00:00, 72.94it/s, epoch=33/200, avg_epoch_loss=9.58]
# 100%|██████████| 50/50 [00:00<00:00, 77.99it/s, epoch=34/200, avg_epoch_loss=9.18]
# 100%|██████████| 50/50 [00:00<00:00, 75.61it/s, epoch=35/200, avg_epoch_loss=9.11]
# 100%|██████████| 50/50 [00:00<00:00, 72.04it/s, epoch=36/200, avg_epoch_loss=9.66]
# 100%|██████████| 50/50 [00:00<00:00, 71.76it/s, epoch=37/200, avg_epoch_loss=9.47]
# 100%|██████████| 50/50 [00:00<00:00, 79.33it/s, epoch=38/200, avg_epoch_loss=9.23]
# 100%|██████████| 50/50 [00:00<00:00, 81.62it/s, epoch=39/200, avg_epoch_loss=9.26]
# 100%|██████████| 50/50 [00:00<00:00, 78.08it/s, epoch=40/200, avg_epoch_loss=9.26]
# 100%|██████████| 50/50 [00:00<00:00, 78.19it/s, epoch=41/200, avg_epoch_loss=9.21]
# 100%|██████████| 50/50 [00:00<00:00, 72.18it/s, epoch=42/200, avg_epoch_loss=9.24]
# 100%|██████████| 50/50 [00:00<00:00, 76.30it/s, epoch=43/200, avg_epoch_loss=9.27]
# 100%|██████████| 50/50 [00:00<00:00, 72.10it/s, epoch=44/200, avg_epoch_loss=9.27]
# 100%|██████████| 50/50 [00:00<00:00, 74.72it/s, epoch=45/200, avg_epoch_loss=9.19]
# 100%|██████████| 50/50 [00:00<00:00, 78.39it/s, epoch=46/200, avg_epoch_loss=8.93]
# 100%|██████████| 50/50 [00:00<00:00, 78.18it/s, epoch=47/200, avg_epoch_loss=8.98]
# 100%|██████████| 50/50 [00:00<00:00, 78.52it/s, epoch=48/200, avg_epoch_loss=8.95]
# 100%|██████████| 50/50 [00:00<00:00, 79.94it/s, epoch=49/200, avg_epoch_loss=8.98]
# 100%|██████████| 50/50 [00:00<00:00, 77.83it/s, epoch=50/200, avg_epoch_loss=8.9]
# 100%|██████████| 50/50 [00:00<00:00, 80.42it/s, epoch=51/200, avg_epoch_loss=8.93]
# 100%|██████████| 50/50 [00:00<00:00, 77.20it/s, epoch=52/200, avg_epoch_loss=8.87]
# 100%|██████████| 50/50 [00:00<00:00, 77.10it/s, epoch=53/200, avg_epoch_loss=8.92]
# 100%|██████████| 50/50 [00:00<00:00, 77.83it/s, epoch=54/200, avg_epoch_loss=8.88]
# 100%|██████████| 50/50 [00:00<00:00, 78.48it/s, epoch=55/200, avg_epoch_loss=8.88]
# 100%|██████████| 50/50 [00:00<00:00, 72.15it/s, epoch=56/200, avg_epoch_loss=8.85]
# 100%|██████████| 50/50 [00:00<00:00, 73.18it/s, epoch=57/200, avg_epoch_loss=8.91]
# 100%|██████████| 50/50 [00:00<00:00, 76.25it/s, epoch=58/200, avg_epoch_loss=8.8]
# 100%|██████████| 50/50 [00:00<00:00, 74.49it/s, epoch=59/200, avg_epoch_loss=8.82]
# 100%|██████████| 50/50 [00:00<00:00, 77.63it/s, epoch=60/200, avg_epoch_loss=8.88]
# 100%|██████████| 50/50 [00:00<00:00, 77.15it/s, epoch=61/200, avg_epoch_loss=8.87]
# 100%|██████████| 50/50 [00:00<00:00, 73.60it/s, epoch=62/200, avg_epoch_loss=8.85]
# 100%|██████████| 50/50 [00:00<00:00, 77.30it/s, epoch=63/200, avg_epoch_loss=8.83]
# 100%|██████████| 50/50 [00:00<00:00, 76.19it/s, epoch=64/200, avg_epoch_loss=8.91]
# 100%|██████████| 50/50 [00:00<00:00, 79.16it/s, epoch=65/200, avg_epoch_loss=8.87]
# 100%|██████████| 50/50 [00:00<00:00, 78.61it/s, epoch=66/200, avg_epoch_loss=8.91]
# 100%|██████████| 50/50 [00:00<00:00, 77.32it/s, epoch=67/200, avg_epoch_loss=8.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.37it/s, epoch=68/200, avg_epoch_loss=8.83]
# 100%|██████████| 50/50 [00:00<00:00, 71.47it/s, epoch=69/200, avg_epoch_loss=8.66]
# 100%|██████████| 50/50 [00:00<00:00, 75.39it/s, epoch=70/200, avg_epoch_loss=8.56]
# 100%|██████████| 50/50 [00:00<00:00, 77.46it/s, epoch=71/200, avg_epoch_loss=8.59]
# 100%|██████████| 50/50 [00:00<00:00, 80.48it/s, epoch=72/200, avg_epoch_loss=8.53]
# 100%|██████████| 50/50 [00:00<00:00, 78.30it/s, epoch=73/200, avg_epoch_loss=8.55]
# 100%|██████████| 50/50 [00:00<00:00, 77.24it/s, epoch=74/200, avg_epoch_loss=8.54]
# 100%|██████████| 50/50 [00:00<00:00, 78.88it/s, epoch=75/200, avg_epoch_loss=8.5]
# 100%|██████████| 50/50 [00:00<00:00, 74.58it/s, epoch=76/200, avg_epoch_loss=8.52]
# 100%|██████████| 50/50 [00:00<00:00, 72.75it/s, epoch=77/200, avg_epoch_loss=8.56]
# 100%|██████████| 50/50 [00:00<00:00, 72.26it/s, epoch=78/200, avg_epoch_loss=8.45]
# 100%|██████████| 50/50 [00:00<00:00, 77.18it/s, epoch=79/200, avg_epoch_loss=8.51]
# 100%|██████████| 50/50 [00:00<00:00, 77.03it/s, epoch=80/200, avg_epoch_loss=8.48]
# 100%|██████████| 50/50 [00:00<00:00, 77.10it/s, epoch=81/200, avg_epoch_loss=8.53]
# 100%|██████████| 50/50 [00:00<00:00, 76.29it/s, epoch=82/200, avg_epoch_loss=8.44]
# 100%|██████████| 50/50 [00:00<00:00, 78.24it/s, epoch=83/200, avg_epoch_loss=8.46]
# 100%|██████████| 50/50 [00:00<00:00, 79.24it/s, epoch=84/200, avg_epoch_loss=8.44]
# 100%|██████████| 50/50 [00:00<00:00, 77.77it/s, epoch=85/200, avg_epoch_loss=8.53]
# 100%|██████████| 50/50 [00:00<00:00, 78.03it/s, epoch=86/200, avg_epoch_loss=8.5]
# 100%|██████████| 50/50 [00:00<00:00, 82.12it/s, epoch=87/200, avg_epoch_loss=8.45]
# 100%|██████████| 50/50 [00:00<00:00, 73.51it/s, epoch=88/200, avg_epoch_loss=8.46]
# 100%|██████████| 50/50 [00:00<00:00, 74.48it/s, epoch=89/200, avg_epoch_loss=8.42]
# 100%|██████████| 50/50 [00:00<00:00, 78.10it/s, epoch=90/200, avg_epoch_loss=8.47]
# 100%|██████████| 50/50 [00:00<00:00, 76.07it/s, epoch=91/200, avg_epoch_loss=8.43]
# 100%|██████████| 50/50 [00:00<00:00, 77.02it/s, epoch=92/200, avg_epoch_loss=8.46]
# 100%|██████████| 50/50 [00:00<00:00, 76.20it/s, epoch=93/200, avg_epoch_loss=8.38]
# 100%|██████████| 50/50 [00:00<00:00, 76.97it/s, epoch=94/200, avg_epoch_loss=8.49]
# 100%|██████████| 50/50 [00:00<00:00, 79.04it/s, epoch=95/200, avg_epoch_loss=8.42]
# 100%|██████████| 50/50 [00:00<00:00, 77.87it/s, epoch=96/200, avg_epoch_loss=8.49]
# 100%|██████████| 50/50 [00:00<00:00, 74.70it/s, epoch=97/200, avg_epoch_loss=8.37]
# 100%|██████████| 50/50 [00:00<00:00, 73.10it/s, epoch=98/200, avg_epoch_loss=8.46]
# 100%|██████████| 50/50 [00:00<00:00, 77.98it/s, epoch=99/200, avg_epoch_loss=8.46]
# 100%|██████████| 50/50 [00:00<00:00, 73.50it/s, epoch=100/200, avg_epoch_loss=8.4]
# 100%|██████████| 50/50 [00:00<00:00, 71.21it/s, epoch=101/200, avg_epoch_loss=8.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.94it/s, epoch=102/200, avg_epoch_loss=8.45]
# 100%|██████████| 50/50 [00:00<00:00, 72.94it/s, epoch=103/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 77.89it/s, epoch=104/200, avg_epoch_loss=8.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.78it/s, epoch=105/200, avg_epoch_loss=8.43]
# 100%|██████████| 50/50 [00:00<00:00, 74.76it/s, epoch=106/200, avg_epoch_loss=8.74]
# 100%|██████████| 50/50 [00:00<00:00, 75.42it/s, epoch=107/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 75.66it/s, epoch=108/200, avg_epoch_loss=8.4]
# 100%|██████████| 50/50 [00:00<00:00, 76.89it/s, epoch=109/200, avg_epoch_loss=8.35]
# 100%|██████████| 50/50 [00:00<00:00, 76.41it/s, epoch=110/200, avg_epoch_loss=8.36]
# 100%|██████████| 50/50 [00:00<00:00, 77.79it/s, epoch=111/200, avg_epoch_loss=8.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.86it/s, epoch=112/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 73.16it/s, epoch=113/200, avg_epoch_loss=8.43]
# 100%|██████████| 50/50 [00:00<00:00, 76.84it/s, epoch=114/200, avg_epoch_loss=8.37]
# 100%|██████████| 50/50 [00:00<00:00, 78.89it/s, epoch=115/200, avg_epoch_loss=8.37]
# 100%|██████████| 50/50 [00:00<00:00, 80.44it/s, epoch=116/200, avg_epoch_loss=8.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.40it/s, epoch=117/200, avg_epoch_loss=8.36]
# 100%|██████████| 50/50 [00:00<00:00, 76.94it/s, epoch=118/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 78.74it/s, epoch=119/200, avg_epoch_loss=8.38]
# 100%|██████████| 50/50 [00:00<00:00, 77.49it/s, epoch=120/200, avg_epoch_loss=8.37]
# 100%|██████████| 50/50 [00:00<00:00, 78.15it/s, epoch=121/200, avg_epoch_loss=8.33]
# 100%|██████████| 50/50 [00:00<00:00, 71.82it/s, epoch=122/200, avg_epoch_loss=8.38]
# 100%|██████████| 50/50 [00:00<00:00, 78.02it/s, epoch=123/200, avg_epoch_loss=8.41]
# 100%|██████████| 50/50 [00:00<00:00, 76.90it/s, epoch=124/200, avg_epoch_loss=8.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.37it/s, epoch=125/200, avg_epoch_loss=8.26]
# 100%|██████████| 50/50 [00:00<00:00, 75.55it/s, epoch=126/200, avg_epoch_loss=8.34]
# 100%|██████████| 50/50 [00:00<00:00, 76.32it/s, epoch=127/200, avg_epoch_loss=8.34]
# 100%|██████████| 50/50 [00:00<00:00, 70.59it/s, epoch=128/200, avg_epoch_loss=8.36]
# 100%|██████████| 50/50 [00:00<00:00, 79.20it/s, epoch=129/200, avg_epoch_loss=8.35]
# 100%|██████████| 50/50 [00:00<00:00, 76.15it/s, epoch=130/200, avg_epoch_loss=8.37]
# 100%|██████████| 50/50 [00:00<00:00, 77.27it/s, epoch=131/200, avg_epoch_loss=8.42]
# 100%|██████████| 50/50 [00:00<00:00, 74.40it/s, epoch=132/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 78.16it/s, epoch=133/200, avg_epoch_loss=8.33]
# 100%|██████████| 50/50 [00:00<00:00, 77.27it/s, epoch=134/200, avg_epoch_loss=8.32]
# 100%|██████████| 50/50 [00:00<00:00, 77.31it/s, epoch=135/200, avg_epoch_loss=8.39]
# 100%|██████████| 50/50 [00:00<00:00, 75.86it/s, epoch=136/200, avg_epoch_loss=8.15]
# 100%|██████████| 50/50 [00:00<00:00, 74.56it/s, epoch=137/200, avg_epoch_loss=8.11]
# 100%|██████████| 50/50 [00:00<00:00, 75.25it/s, epoch=138/200, avg_epoch_loss=8]
# 100%|██████████| 50/50 [00:00<00:00, 79.31it/s, epoch=139/200, avg_epoch_loss=8.05]
# 100%|██████████| 50/50 [00:00<00:00, 73.89it/s, epoch=140/200, avg_epoch_loss=7.96]
# 100%|██████████| 50/50 [00:00<00:00, 72.37it/s, epoch=141/200, avg_epoch_loss=8]
# 100%|██████████| 50/50 [00:00<00:00, 73.31it/s, epoch=142/200, avg_epoch_loss=7.96]
# 100%|██████████| 50/50 [00:00<00:00, 69.90it/s, epoch=143/200, avg_epoch_loss=7.87]
# 100%|██████████| 50/50 [00:00<00:00, 73.45it/s, epoch=144/200, avg_epoch_loss=7.89]
# 100%|██████████| 50/50 [00:00<00:00, 76.73it/s, epoch=145/200, avg_epoch_loss=7.88]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=146/200, avg_epoch_loss=7.86]
# 100%|██████████| 50/50 [00:00<00:00, 78.87it/s, epoch=147/200, avg_epoch_loss=7.8]
# 100%|██████████| 50/50 [00:00<00:00, 79.90it/s, epoch=148/200, avg_epoch_loss=7.83]
# 100%|██████████| 50/50 [00:00<00:00, 79.09it/s, epoch=149/200, avg_epoch_loss=7.83]
# 100%|██████████| 50/50 [00:00<00:00, 78.71it/s, epoch=150/200, avg_epoch_loss=7.8]
# 100%|██████████| 50/50 [00:00<00:00, 80.70it/s, epoch=151/200, avg_epoch_loss=7.77]
# 100%|██████████| 50/50 [00:00<00:00, 76.01it/s, epoch=152/200, avg_epoch_loss=7.83]
# 100%|██████████| 50/50 [00:00<00:00, 76.93it/s, epoch=153/200, avg_epoch_loss=7.66]
# 100%|██████████| 50/50 [00:00<00:00, 76.06it/s, epoch=154/200, avg_epoch_loss=7.77]
# 100%|██████████| 50/50 [00:00<00:00, 77.44it/s, epoch=155/200, avg_epoch_loss=7.7]
# 100%|██████████| 50/50 [00:00<00:00, 78.66it/s, epoch=156/200, avg_epoch_loss=7.75]
# 100%|██████████| 50/50 [00:00<00:00, 77.64it/s, epoch=157/200, avg_epoch_loss=7.72]
# 100%|██████████| 50/50 [00:00<00:00, 77.76it/s, epoch=158/200, avg_epoch_loss=7.64]
# 100%|██████████| 50/50 [00:00<00:00, 78.99it/s, epoch=159/200, avg_epoch_loss=7.7]
# 100%|██████████| 50/50 [00:00<00:00, 77.97it/s, epoch=160/200, avg_epoch_loss=7.67]
# 100%|██████████| 50/50 [00:00<00:00, 78.55it/s, epoch=161/200, avg_epoch_loss=7.69]
# 100%|██████████| 50/50 [00:00<00:00, 78.82it/s, epoch=162/200, avg_epoch_loss=7.73]
# 100%|██████████| 50/50 [00:00<00:00, 77.62it/s, epoch=163/200, avg_epoch_loss=7.63]
# 100%|██████████| 50/50 [00:00<00:00, 78.61it/s, epoch=164/200, avg_epoch_loss=7.63]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=165/200, avg_epoch_loss=7.62]
# 100%|██████████| 50/50 [00:00<00:00, 78.41it/s, epoch=166/200, avg_epoch_loss=7.64]
# 100%|██████████| 50/50 [00:00<00:00, 78.17it/s, epoch=167/200, avg_epoch_loss=7.62]
# 100%|██████████| 50/50 [00:00<00:00, 75.74it/s, epoch=168/200, avg_epoch_loss=7.64]
# 100%|██████████| 50/50 [00:00<00:00, 67.84it/s, epoch=169/200, avg_epoch_loss=7.67]
# 100%|██████████| 50/50 [00:00<00:00, 74.29it/s, epoch=170/200, avg_epoch_loss=7.66]
# 100%|██████████| 50/50 [00:00<00:00, 75.33it/s, epoch=171/200, avg_epoch_loss=7.65]
# 100%|██████████| 50/50 [00:00<00:00, 72.47it/s, epoch=172/200, avg_epoch_loss=7.68]
# 100%|██████████| 50/50 [00:00<00:00, 72.92it/s, epoch=173/200, avg_epoch_loss=7.66]
# 100%|██████████| 50/50 [00:00<00:00, 74.79it/s, epoch=174/200, avg_epoch_loss=7.64]
# 100%|██████████| 50/50 [00:00<00:00, 75.10it/s, epoch=175/200, avg_epoch_loss=7.62]
# 100%|██████████| 50/50 [00:00<00:00, 71.73it/s, epoch=176/200, avg_epoch_loss=7.66]
# 100%|██████████| 50/50 [00:00<00:00, 75.74it/s, epoch=177/200, avg_epoch_loss=7.62]

# %%
from gluonts.evaluation.backtest import make_evaluation_predictions

test_data = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values,
      "feat_dynamic_real": [temp['유동자산(요약)'].values,temp['매출총이익(요약)'].values,temp['매출액(요약)'].values,temp['당기순이익(요약)'].values]}],
    freq = "365D"
)

forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_data,  # test dataset
    predictor=predictor ,  # predictor
    num_samples=1,  # number of sample paths we want for evaluation
)

# %%
answer_data = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values}],
    freq = "365D"
)

# %%
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
train_entry = next(iter(forecasts))
train_entry
# Out:
# gluonts.model.forecast.SampleForecast(freq="365D", info=None, item_id=None, samples=numpy.array([[828457.5]], numpy.dtype("float32")), start_date=pandas.Timestamp("2022-12-19 00:00:00", freq="365D"))

# %%
train_entry.samples
# Out:
# array([[828457.5]], dtype=float32)

# %%
predict = train_entry.samples

# %%
predict[0][0]
# Out:
# 828457.5

# %%
answer = temp['영업이익(요약)'].values[-prediction_window:]

# %%
answer[0]
# Out:
# 642062.375

# %%
RMSE = mean_squared_error(answer,predict[0])**0.5

# %%
RMSE
# Out:
# 186395.125
