# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys

nb_path = '/content/drive/MyDrive/Colab Notebooks/site-packages'
sys.path.insert(0, nb_path)  # or append(nb_path)

# %%
# Standard library imports
import numpy as np

from gluonts.dataset.common import ListDataset
from gluonts.model.estimator import GluonEstimator
from gluonts.model.predictor import Predictor
from gluonts.trainer import Trainer

import mxnet as mx
from mxnet import gluon
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx.trainer import Trainer
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: gluonts.trainer is deprecated. Use gluonts.mx.trainer instead.
#   import sys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error

# %%
mx.random.seed(0)
np.random.seed(0)

# %% [markdown]
# ## **deepAR**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ppikppik/outfree_gs_boo.csv", encoding='EUC-KR')

# %%
year_start = 1985
month = 12
day = 1
cnt_year = 0
for i in df.index :
  df.loc[i,'회계년도'] = pd.Timestamp(year=year_start+cnt_year, month=12, day=1)
  cnt_year = cnt_year + 1

# %%
temp = df.set_index(df['회계년도'])
temp[{'자본총계(요약)', '당기순이익(요약)', '판매비와 관리비(요약)', '유동자산(요약)', '영업이익(요약)'}]
# Out:
#             유동자산(요약)  자본총계(요약)  당기순이익(요약)  판매비와 관리비(요약)  영업이익(요약)
# 회계년도
# 1985-12-01     93153     14980     2444.0        6248.0    2576.0
# 1986-12-01    110459     23318     3818.0        7754.0    7120.0
# 1987-12-01    129208     27154     4748.0        9298.0   11035.0
# 1988-12-01    140120     28824     3135.0       11695.0   11398.0
# 1989-12-01    157434     30091     1587.0       10952.0    9807.0
# 1990-12-01    200084     29108     1637.0        9641.0   19810.0
# 1991-12-01    188209     42230     3002.0        9765.0   13032.0
# 1992-12-01    283401     98406    10295.0       13190.0   19108.0
# 1993-12-01    360086    108047    14174.0       16619.0   28015.0
# 1994-12-01    537065    140052    16173.0       19798.0   54482.0
# 1995-12-01    644659    151211    19318.0       29149.0   59159.0
# 1996-12-01    875692    196618    15763.0       42869.0   77714.0
# 1997-12-01    880767    231200    10571.0       51048.0   80541.0
# 1998-12-01    977137    265484     9834.0       67081.0   88619.0
# 1999-12-01   1191673    271401    19608.0       77292.0  111660.0
# 2000-12-01   1386759    276718    15384.0      113583.0  127423.0
# 2001-12-01   1533136    264865    19811.0      115338.0   98718.0
# 2002-12-01   1456663    485751    41501.0       92117.0  110501.0
# 2003-12-01   1473119    706637    99839.0      136200.0  143284.0
# 2004-12-01   1229534    742374   123594.0      154073.0  225429.0
# 2005-12-01   1456656    887363   150078.0      150083.0  254845.0
# 2006-12-01   1301303   1048669   160714.0      196436.0  276065.0
# 2007-12-01   1297856   1155628   161537.0      249596.0  271411.0
# 2008-12-01   1774927   1297385   213337.5      263123.0  229122.0
# 2009-12-01   2422545   1450838   265138.0      344414.0  335578.0
# 2010-12-01   3018745   1784467   386953.0      358829.0  403370.0
# 2011-12-01   3758242   2132179   400013.0      417574.0  442044.0
# 2012-12-01   4927769   2310761   381554.0      434641.0  478323.0
# 2013-12-01   5894188   2489344   382801.0      462243.5  392046.2
# 2014-12-01   6551877   2667926   388676.9      489846.0  305769.5
# 2015-12-01   6792046   2846508   394552.8      475314.3  219492.8
# 2016-12-01   7032214   3025090   400428.7      460782.7  133216.0
# 2017-12-01   7503603   3203673   406304.6      446251.0  134874.7
# 2018-12-01   7667877   3382255   412180.5      445280.8  136533.3
# 2019-12-01   7502377   3363872   418056.4      444310.5  138192.0
# 2020-12-01   7336877   3499964   423932.3      443340.2  387819.0
# 2021-12-01   7171377   3636056   429808.2      442370.0  532659.0
# 2022-12-01   7005877   3772148   435684.1      513816.0  981918.0
# 2023-12-01   5997754   4161407   441560.0      576918.0  680931.0

# %%
def find_upper_lower_bound(df,col):
    temp = sorted(df[col])
    q1, q3 = np.percentile(temp, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    return lower_bound, upper_bound

def range_check_correct(df,col):
    cor_range = find_upper_lower_bound(df,col)
    print(cor_range)
    for i in df.index:
        if df.loc[i][col] < (float)(cor_range[0]) :
            df[col][i] = (float)(cor_range[0])
        if df.loc[i][col] > (float)(cor_range[1]) :
            df[col][i] = (float)(cor_range[1])
    return df

# %%
temp = range_check_correct(temp,'영업이익(요약)')
# Out:
# (-294324.625, 642062.375)

# %%
temp
# Out:
#                  회사명    연도  거래소코드  ...       부채비용     비유동비율  비유동장기적합률
# 회계년도                               ...
# 1985-12-01  지에스건설(주)  1981   6360  ...  18.597705  0.260653  2.306329
# 1986-12-01  지에스건설(주)  1982   6360  ...  10.528852  0.749201  0.957382
# 1987-12-01  지에스건설(주)  1983   6360  ...  11.416639  0.517862  1.182656
# 1988-12-01  지에스건설(주)  1984   6360  ...  12.595984  0.721935  0.990255
# 1989-12-01  지에스건설(주)  1985   6360  ...  14.482049  0.759678  0.993096
# 1990-12-01  지에스건설(주)  1986   6360  ...  18.025246  1.154299  0.712439
# 1991-12-01  지에스건설(주)  1987   6360  ...   7.433893  1.853399  0.393315
# 1992-12-01  지에스건설(주)  1988   6360  ...   6.215350  1.187303  0.550647
# 1993-12-01  지에스건설(주)  1989   6360  ...   9.496575  1.111082  0.702241
# 1994-12-01  지에스건설(주)  1990   6360  ...  11.978126  1.079809  0.737432
# 1995-12-01  지에스건설(주)  1991   6360  ...  14.269137  1.079051  0.748093
# 1996-12-01  지에스건설(주)  1992   6360  ...  20.136863  0.935439  0.903624
# 1997-12-01  지에스건설(주)  1993   6360  ...  13.615721  0.760623  0.993313
# 1998-12-01  지에스건설(주)  1994   6360  ...  13.120773  1.006385  0.810218
# 1999-12-01  지에스건설(주)  1995   6360  ...  15.609129  1.307970  0.649524
# 2000-12-01  지에스건설(주)  1996   6360  ...  18.796994  0.857815  0.951491
# 2001-12-01  지에스건설(주)  1997   6360  ...  19.789052  1.334122  0.668025
# 2002-12-01  지에스건설(주)  1998   6360  ...  18.422123  1.223480  0.725384
# 2003-12-01  지에스건설(주)  1999   6360  ...   6.725431  0.275457  1.837216
# 2004-12-01  지에스건설(주)  2000   6360  ...   6.432000  0.428287  1.539767
# 2005-12-01  지에스건설(주)  2001   6360  ...   6.872357  0.445118  1.513676
# 2006-12-01  지에스건설(주)  2002   6360  ...   6.326369  0.358099  1.833122
# 2007-12-01  지에스건설(주)  2003   6360  ...   6.018839  0.251478  2.301010
# 2008-12-01  지에스건설(주)  2004   6360  ...   7.866176  0.327920  2.021149
# 2009-12-01  지에스건설(주)  2005   6360  ...   9.313722  0.374700  1.797217
# 2010-12-01  지에스건설(주)  2006   6360  ...  11.635114  0.336004  2.069643
# 2011-12-01  지에스건설(주)  2007   6360  ...  14.091804  0.328463  2.183027
# 2012-12-01  지에스건설(주)  2008   6360  ...  20.185349  0.417415  2.017072
# 2013-12-01  지에스건설(주)  2009   6360  ...  22.146055  0.476105  1.786816
# 2014-12-01  지에스건설(주)  2010   6360  ...  22.558584  0.418088  1.962303
# 2015-12-01  지에스건설(주)  2011   6360  ...  25.587200  0.538732  1.594405
# 2016-12-01  지에스건설(주)  2012   6360  ...  24.964243  0.535087  1.625563
# 2017-12-01  지에스건설(주)  2013   6360  ...  30.790875  0.667411  1.344325
# 2018-12-01  지에스건설(주)  2014   6360  ...  22.896394  0.665998  1.318595
# 2019-12-01  지에스건설(주)  2015   6360  ...  23.853017  0.658198  1.313297
# 2020-12-01  지에스건설(주)  2016   6360  ...  25.193363  0.704571  1.242580
# 2021-12-01  지에스건설(주)  2017   6360  ...  26.105568  0.374547  2.177669
# 2022-12-01  지에스건설(주)  2018   6360  ...  18.381377  0.380281  2.092309
# 2023-12-01  지에스건설(주)  2019   6360  ...  18.260879  0.437339  1.959010
#
# [39 rows x 27 columns]

# %%
prediction_window = 1

# %%
train_ds = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values[:-prediction_window] ,
      "feat_dynamic_real": [temp['자본총계(요약)'].values[:-prediction_window],temp['당기순이익(요약)'].values[:-prediction_window],temp['판매비와 관리비(요약)'].values[:-prediction_window],temp['유동자산(요약)'].values[:-prediction_window]]}],
                        freq = "365D"
)

# %%
freq = "365D"

estimator = DeepAREstimator(prediction_length = prediction_window, use_feat_dynamic_real= True , freq=freq, cell_type = 'lstm', 
                           trainer=Trainer(epochs=200, ctx = mx.context.gpu(),))

# %%
predictor = estimator.train(training_data = train_ds)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# 100%|██████████| 50/50 [00:08<00:00,  6.10it/s, epoch=1/200, avg_epoch_loss=13.8]
# 100%|██████████| 50/50 [00:00<00:00, 74.43it/s, epoch=2/200, avg_epoch_loss=12.5]
# 100%|██████████| 50/50 [00:00<00:00, 73.25it/s, epoch=3/200, avg_epoch_loss=11.7]
# 100%|██████████| 50/50 [00:00<00:00, 67.46it/s, epoch=4/200, avg_epoch_loss=11.2]
# 100%|██████████| 50/50 [00:00<00:00, 70.62it/s, epoch=5/200, avg_epoch_loss=10.7]
# 100%|██████████| 50/50 [00:00<00:00, 75.27it/s, epoch=6/200, avg_epoch_loss=10.3]
# 100%|██████████| 50/50 [00:00<00:00, 71.22it/s, epoch=7/200, avg_epoch_loss=10]
# 100%|██████████| 50/50 [00:00<00:00, 69.52it/s, epoch=8/200, avg_epoch_loss=10.1]
# 100%|██████████| 50/50 [00:00<00:00, 71.30it/s, epoch=9/200, avg_epoch_loss=10.1]
# 100%|██████████| 50/50 [00:00<00:00, 71.69it/s, epoch=10/200, avg_epoch_loss=9.96]
# 100%|██████████| 50/50 [00:00<00:00, 73.32it/s, epoch=11/200, avg_epoch_loss=9.67]
# 100%|██████████| 50/50 [00:00<00:00, 77.42it/s, epoch=12/200, avg_epoch_loss=9.83]
# 100%|██████████| 50/50 [00:00<00:00, 78.59it/s, epoch=13/200, avg_epoch_loss=10]
# 100%|██████████| 50/50 [00:00<00:00, 73.12it/s, epoch=14/200, avg_epoch_loss=9.86]
# 100%|██████████| 50/50 [00:00<00:00, 72.87it/s, epoch=15/200, avg_epoch_loss=9.76]
# 100%|██████████| 50/50 [00:00<00:00, 77.66it/s, epoch=16/200, avg_epoch_loss=9.76]
# 100%|██████████| 50/50 [00:00<00:00, 74.42it/s, epoch=17/200, avg_epoch_loss=9.84]
# 100%|██████████| 50/50 [00:00<00:00, 72.72it/s, epoch=18/200, avg_epoch_loss=9.84]
# 100%|██████████| 50/50 [00:00<00:00, 71.40it/s, epoch=19/200, avg_epoch_loss=9.61]
# 100%|██████████| 50/50 [00:00<00:00, 72.50it/s, epoch=20/200, avg_epoch_loss=9.69]
# 100%|██████████| 50/50 [00:00<00:00, 73.50it/s, epoch=21/200, avg_epoch_loss=9.82]
# 100%|██████████| 50/50 [00:00<00:00, 77.74it/s, epoch=22/200, avg_epoch_loss=9.82]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=23/200, avg_epoch_loss=9.74]
# 100%|██████████| 50/50 [00:00<00:00, 76.50it/s, epoch=24/200, avg_epoch_loss=9.69]
# 100%|██████████| 50/50 [00:00<00:00, 77.44it/s, epoch=25/200, avg_epoch_loss=9.61]
# 100%|██████████| 50/50 [00:00<00:00, 78.86it/s, epoch=26/200, avg_epoch_loss=9.6]
# 100%|██████████| 50/50 [00:00<00:00, 76.54it/s, epoch=27/200, avg_epoch_loss=9.58]
# 100%|██████████| 50/50 [00:00<00:00, 74.39it/s, epoch=28/200, avg_epoch_loss=11.4]
# 100%|██████████| 50/50 [00:00<00:00, 74.31it/s, epoch=29/200, avg_epoch_loss=12.6]
# 100%|██████████| 50/50 [00:00<00:00, 73.46it/s, epoch=30/200, avg_epoch_loss=11.8]
# 100%|██████████| 50/50 [00:00<00:00, 73.20it/s, epoch=31/200, avg_epoch_loss=11.6]
# 100%|██████████| 50/50 [00:00<00:00, 71.83it/s, epoch=32/200, avg_epoch_loss=11.4]
# 100%|██████████| 50/50 [00:00<00:00, 72.51it/s, epoch=33/200, avg_epoch_loss=11.3]
# 100%|██████████| 50/50 [00:00<00:00, 72.80it/s, epoch=34/200, avg_epoch_loss=11.1]
# 100%|██████████| 50/50 [00:00<00:00, 70.22it/s, epoch=35/200, avg_epoch_loss=11]
# 100%|██████████| 50/50 [00:00<00:00, 76.16it/s, epoch=36/200, avg_epoch_loss=10.7]
# 100%|██████████| 50/50 [00:00<00:00, 77.31it/s, epoch=37/200, avg_epoch_loss=10.5]
# 100%|██████████| 50/50 [00:00<00:00, 72.84it/s, epoch=38/200, avg_epoch_loss=9.49]
# 100%|██████████| 50/50 [00:00<00:00, 76.62it/s, epoch=39/200, avg_epoch_loss=9.39]
# 100%|██████████| 50/50 [00:00<00:00, 70.88it/s, epoch=40/200, avg_epoch_loss=9.41]
# 100%|██████████| 50/50 [00:00<00:00, 72.34it/s, epoch=41/200, avg_epoch_loss=9.4]
# 100%|██████████| 50/50 [00:00<00:00, 77.41it/s, epoch=42/200, avg_epoch_loss=9.32]
# 100%|██████████| 50/50 [00:00<00:00, 76.10it/s, epoch=43/200, avg_epoch_loss=9.3]
# 100%|██████████| 50/50 [00:00<00:00, 72.32it/s, epoch=44/200, avg_epoch_loss=9.47]
# 100%|██████████| 50/50 [00:00<00:00, 75.92it/s, epoch=45/200, avg_epoch_loss=9.13]
# 100%|██████████| 50/50 [00:00<00:00, 74.28it/s, epoch=46/200, avg_epoch_loss=9.43]
# 100%|██████████| 50/50 [00:00<00:00, 76.55it/s, epoch=47/200, avg_epoch_loss=9.35]
# 100%|██████████| 50/50 [00:00<00:00, 74.56it/s, epoch=48/200, avg_epoch_loss=9.23]
# 100%|██████████| 50/50 [00:00<00:00, 75.76it/s, epoch=49/200, avg_epoch_loss=9.22]
# 100%|██████████| 50/50 [00:00<00:00, 70.04it/s, epoch=50/200, avg_epoch_loss=9.35]
# 100%|██████████| 50/50 [00:00<00:00, 75.70it/s, epoch=51/200, avg_epoch_loss=9.17]
# 100%|██████████| 50/50 [00:00<00:00, 78.17it/s, epoch=52/200, avg_epoch_loss=9.24]
# 100%|██████████| 50/50 [00:00<00:00, 75.35it/s, epoch=53/200, avg_epoch_loss=9.3]
# 100%|██████████| 50/50 [00:00<00:00, 77.54it/s, epoch=54/200, avg_epoch_loss=9.58]
# 100%|██████████| 50/50 [00:00<00:00, 79.30it/s, epoch=55/200, avg_epoch_loss=9.16]
# 100%|██████████| 50/50 [00:00<00:00, 70.99it/s, epoch=56/200, avg_epoch_loss=9.03]
# 100%|██████████| 50/50 [00:00<00:00, 76.98it/s, epoch=57/200, avg_epoch_loss=9.03]
# 100%|██████████| 50/50 [00:00<00:00, 74.14it/s, epoch=58/200, avg_epoch_loss=9.04]
# 100%|██████████| 50/50 [00:00<00:00, 75.38it/s, epoch=59/200, avg_epoch_loss=8.99]
# 100%|██████████| 50/50 [00:00<00:00, 78.33it/s, epoch=60/200, avg_epoch_loss=8.99]
# 100%|██████████| 50/50 [00:00<00:00, 75.54it/s, epoch=61/200, avg_epoch_loss=8.93]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=62/200, avg_epoch_loss=8.8]
# 100%|██████████| 50/50 [00:00<00:00, 76.36it/s, epoch=63/200, avg_epoch_loss=9.07]
# 100%|██████████| 50/50 [00:00<00:00, 79.67it/s, epoch=64/200, avg_epoch_loss=9.09]
# 100%|██████████| 50/50 [00:00<00:00, 75.71it/s, epoch=65/200, avg_epoch_loss=8.95]
# 100%|██████████| 50/50 [00:00<00:00, 78.43it/s, epoch=66/200, avg_epoch_loss=8.87]
# 100%|██████████| 50/50 [00:00<00:00, 77.73it/s, epoch=67/200, avg_epoch_loss=8.96]
# 100%|██████████| 50/50 [00:00<00:00, 76.86it/s, epoch=68/200, avg_epoch_loss=8.93]
# 100%|██████████| 50/50 [00:00<00:00, 76.90it/s, epoch=69/200, avg_epoch_loss=9.35]
# 100%|██████████| 50/50 [00:00<00:00, 79.40it/s, epoch=70/200, avg_epoch_loss=9.27]
# 100%|██████████| 50/50 [00:00<00:00, 78.01it/s, epoch=71/200, avg_epoch_loss=9.18]
# 100%|██████████| 50/50 [00:00<00:00, 74.65it/s, epoch=72/200, avg_epoch_loss=9.18]
# 100%|██████████| 50/50 [00:00<00:00, 76.94it/s, epoch=73/200, avg_epoch_loss=9.11]
# 100%|██████████| 50/50 [00:00<00:00, 78.05it/s, epoch=74/200, avg_epoch_loss=8.73]
# 100%|██████████| 50/50 [00:00<00:00, 77.95it/s, epoch=75/200, avg_epoch_loss=8.65]
# 100%|██████████| 50/50 [00:00<00:00, 76.36it/s, epoch=76/200, avg_epoch_loss=8.64]
# 100%|██████████| 50/50 [00:00<00:00, 79.54it/s, epoch=77/200, avg_epoch_loss=8.66]
# 100%|██████████| 50/50 [00:00<00:00, 77.90it/s, epoch=78/200, avg_epoch_loss=8.58]
# 100%|██████████| 50/50 [00:00<00:00, 77.39it/s, epoch=79/200, avg_epoch_loss=8.67]
# 100%|██████████| 50/50 [00:00<00:00, 75.51it/s, epoch=80/200, avg_epoch_loss=8.58]
# 100%|██████████| 50/50 [00:00<00:00, 75.35it/s, epoch=81/200, avg_epoch_loss=8.66]
# 100%|██████████| 50/50 [00:00<00:00, 75.19it/s, epoch=82/200, avg_epoch_loss=8.68]
# 100%|██████████| 50/50 [00:00<00:00, 77.24it/s, epoch=83/200, avg_epoch_loss=8.66]
# 100%|██████████| 50/50 [00:00<00:00, 74.61it/s, epoch=84/200, avg_epoch_loss=8.9]
# 100%|██████████| 50/50 [00:00<00:00, 76.23it/s, epoch=85/200, avg_epoch_loss=8.63]
# 100%|██████████| 50/50 [00:00<00:00, 74.89it/s, epoch=86/200, avg_epoch_loss=8.6]
# 100%|██████████| 50/50 [00:00<00:00, 78.40it/s, epoch=87/200, avg_epoch_loss=8.62]
# 100%|██████████| 50/50 [00:00<00:00, 69.93it/s, epoch=88/200, avg_epoch_loss=8.61]
# 100%|██████████| 50/50 [00:00<00:00, 69.76it/s, epoch=89/200, avg_epoch_loss=8.57]
# 100%|██████████| 50/50 [00:00<00:00, 74.89it/s, epoch=90/200, avg_epoch_loss=8.59]
# 100%|██████████| 50/50 [00:00<00:00, 76.85it/s, epoch=91/200, avg_epoch_loss=8.56]
# 100%|██████████| 50/50 [00:00<00:00, 73.72it/s, epoch=92/200, avg_epoch_loss=8.64]
# 100%|██████████| 50/50 [00:00<00:00, 80.91it/s, epoch=93/200, avg_epoch_loss=8.57]
# 100%|██████████| 50/50 [00:00<00:00, 76.47it/s, epoch=94/200, avg_epoch_loss=8.49]
# 100%|██████████| 50/50 [00:00<00:00, 76.01it/s, epoch=95/200, avg_epoch_loss=8.56]
# 100%|██████████| 50/50 [00:00<00:00, 75.33it/s, epoch=96/200, avg_epoch_loss=8.57]
# 100%|██████████| 50/50 [00:00<00:00, 74.58it/s, epoch=97/200, avg_epoch_loss=8.5]
# 100%|██████████| 50/50 [00:00<00:00, 77.07it/s, epoch=98/200, avg_epoch_loss=8.47]
# 100%|██████████| 50/50 [00:00<00:00, 74.55it/s, epoch=99/200, avg_epoch_loss=8.62]
# 100%|██████████| 50/50 [00:00<00:00, 67.20it/s, epoch=100/200, avg_epoch_loss=8.55]
# 100%|██████████| 50/50 [00:00<00:00, 71.46it/s, epoch=101/200, avg_epoch_loss=8.45]
# 100%|██████████| 50/50 [00:00<00:00, 70.40it/s, epoch=102/200, avg_epoch_loss=8.42]
# 100%|██████████| 50/50 [00:00<00:00, 70.56it/s, epoch=103/200, avg_epoch_loss=8.52]
# 100%|██████████| 50/50 [00:00<00:00, 74.34it/s, epoch=104/200, avg_epoch_loss=8.64]
# 100%|██████████| 50/50 [00:00<00:00, 70.65it/s, epoch=105/200, avg_epoch_loss=8.43]
# 100%|██████████| 50/50 [00:00<00:00, 72.85it/s, epoch=106/200, avg_epoch_loss=8.49]
# 100%|██████████| 50/50 [00:00<00:00, 72.52it/s, epoch=107/200, avg_epoch_loss=8.53]
# 100%|██████████| 50/50 [00:00<00:00, 71.27it/s, epoch=108/200, avg_epoch_loss=8.51]
# 100%|██████████| 50/50 [00:00<00:00, 76.10it/s, epoch=109/200, avg_epoch_loss=8.5]
# 100%|██████████| 50/50 [00:00<00:00, 73.92it/s, epoch=110/200, avg_epoch_loss=8.5]
# 100%|██████████| 50/50 [00:00<00:00, 74.94it/s, epoch=111/200, avg_epoch_loss=8.49]
# 100%|██████████| 50/50 [00:00<00:00, 76.12it/s, epoch=112/200, avg_epoch_loss=8.44]
# 100%|██████████| 50/50 [00:00<00:00, 77.17it/s, epoch=113/200, avg_epoch_loss=8.64]
# 100%|██████████| 50/50 [00:00<00:00, 78.47it/s, epoch=114/200, avg_epoch_loss=8.61]
# 100%|██████████| 50/50 [00:00<00:00, 70.42it/s, epoch=115/200, avg_epoch_loss=8.63]
# 100%|██████████| 50/50 [00:00<00:00, 73.35it/s, epoch=116/200, avg_epoch_loss=8.62]
# 100%|██████████| 50/50 [00:00<00:00, 71.00it/s, epoch=117/200, avg_epoch_loss=8.63]
# 100%|██████████| 50/50 [00:00<00:00, 72.06it/s, epoch=118/200, avg_epoch_loss=8.6]
# 100%|██████████| 50/50 [00:00<00:00, 72.52it/s, epoch=119/200, avg_epoch_loss=8.59]
# 100%|██████████| 50/50 [00:00<00:00, 71.08it/s, epoch=120/200, avg_epoch_loss=8.59]
# 100%|██████████| 50/50 [00:00<00:00, 70.25it/s, epoch=121/200, avg_epoch_loss=8.62]
# 100%|██████████| 50/50 [00:00<00:00, 71.94it/s, epoch=122/200, avg_epoch_loss=8.64]

# %%
from gluonts.evaluation.backtest import make_evaluation_predictions

test_data = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values,
      "feat_dynamic_real": [temp['자본총계(요약)'].values,temp['당기순이익(요약)'].values,temp['판매비와 관리비(요약)'].values,temp['유동자산(요약)'].values]}],
    freq = "365D"
)

forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_data,  # test dataset
    predictor=predictor ,  # predictor
    num_samples=1,  # number of sample paths we want for evaluation
)

# %%
answer_data = ListDataset(
    [{"start": temp.index[0], "target": temp['영업이익(요약)'].values}],
    freq = "365D"
)

# %%
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
train_entry = next(iter(forecasts))
train_entry
# Out:
# gluonts.model.forecast.SampleForecast(freq="365D", info=None, item_id=None, samples=numpy.array([[580951.75]], numpy.dtype("float32")), start_date=pandas.Timestamp("2022-12-19 00:00:00", freq="365D"))

# %%
train_entry.samples
# Out:
# array([[580951.75]], dtype=float32)

# %%
predict = train_entry.samples

# %%
predict[0][0]
# Out:
# 580951.75

# %%
answer = temp['영업이익(요약)'].values[-prediction_window:]

# %%
answer[0]
# Out:
# 642062.375

# %%
RMSE = mean_squared_error(answer,predict[0])**0.5

# %%
RMSE
# Out:
# 61110.625
